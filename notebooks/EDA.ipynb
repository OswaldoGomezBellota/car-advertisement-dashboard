# %%
import pandas as pd
import plotly.express as px

# Cargar el dataset
car_data = pd.read_csv('vehicles_us.csv')

# Experimentar con histograma
fig = px.histogram(car_data, x="odometer")
fig.show()

# Experimentar con gráfico de dispersión
fig = px.scatter(car_data, x="odometer", y="price")
fig.show()
# Out:
# c:\Users\oswal\anaconda3\envs\Virtual\python.exe

# %%
# Cargar el dataset
car_data = pd.read_csv('vehicles_us.csv')

# Experimentar con histograma
fig = px.histogram(car_data, x="odometer")
fig.show()

# Experimentar con gráfico de dispersión
fig = px.scatter(car_data, x="odometer", y="price")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Cargar el dataset
# ----> 2 car_data = pd.read_csv('vehicles_us.csv')
#       4 # Experimentar con histograma
#       5 fig = px.histogram(car_data, x="odometer")
#
# NameError: name 'pd' is not defined
